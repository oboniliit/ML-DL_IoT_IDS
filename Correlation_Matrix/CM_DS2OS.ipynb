# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd

# %%
nRowsRead = None # specify 'None' if want to read whole file
col_name = ["sourceID", "sourceAddress", "sourceType", "sourceLocation", "destinationServiceAddress",
       "destinationServiceType", "destinationLocation", "accessedNodeAddress", "accessedNodeType", "operation", "value",
       "normality"]
df = pd.read_csv('/content/drive/MyDrive/code/dataset/df_spark.csv', header=0,  names=col_name, delimiter=',', nrows = nRowsRead)
df.dataframeName = 'DS2OS.csv'
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 357941 rows and 12 columns

# %%
df.head()
# Out:
#    sourceID  sourceAddress  sourceType  ...  operation  value  normality
# 0       7.0           21.0        30.0  ...        7.0    2.0        0.0
# 1       7.0           32.0        70.0  ...        7.0    2.0        0.0
# 2       7.0           15.0         1.0  ...        7.0    2.0        0.0
# 3       7.0           33.0        77.0  ...        7.0    2.0        0.0
# 4       7.0           55.0        78.0  ...        8.0    2.0        0.0
#
# [5 rows x 12 columns]

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(16,15))
#plot heat map
g=sns.heatmap(corrmat, cmap ="YlGnBu", vmax=1.0, center=0, vmin= -1.0,
            square=True, linewidths = 0.0) 
# g=sns.heatmap(df[top_corr_features].corr(),cmap="RdYlGn")
plt.savefig('CM_ds2os.pdf')
plt.savefig("CM_ds2os.svg")
plt.savefig("CM_ds2os.png")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
