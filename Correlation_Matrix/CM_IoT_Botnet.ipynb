# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd

# %%
nRowsRead = 200 # specify 'None' if want to read whole file
# Preprossed_data.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('/content/drive/MyDrive/IoT Botnet Dataset 2020/10 _ Dataset_/IoT-BoT.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'IoT-BoT.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 200 rows and 86 columns

# %%
df1.head()
# Out:
#                                     Flow_ID           Src_IP  ...   Cat    Sub_Cat
# 0  192.168.100.147-192.168.100.3-62006-80-6  192.168.100.147  ...  DDoS   DDoS_TCP
# 1  192.168.100.148-192.168.100.7-38320-80-6  192.168.100.148  ...   DoS    DoS_TCP
# 2  192.168.100.148-192.168.100.7-40565-80-6  192.168.100.148  ...   DoS    DoS_TCP
# 3  192.168.100.148-192.168.100.3-39904-80-6  192.168.100.148  ...  DDoS  DDoS_HTTP
# 4  192.168.100.148-192.168.100.7-62340-80-6  192.168.100.148  ...   DoS    DoS_TCP
#
# [5 rows x 86 columns]

# %%
ds = df1.drop(['Fwd_PSH_Flags', 'Fwd_URG_Flags', 'Bwd_URG_Flags', 'FIN_Flag_Cnt', 'URG_Flag_Cnt', 'CWE_Flag_Count', 'ECE_Flag_Cnt', 'Fwd_Byts/b_Avg', 'Fwd_Pkts/b_Avg', 'Fwd_Blk_Rate_Avg', 'Bwd_Byts/b_Avg', 'Bwd_Pkts/b_Avg', 'Bwd_Blk_Rate_Avg', 'Fwd_Seg_Size_Min', 'Init_Fwd_Win_Byts'], axis=1)

# %%
ds.shape
# Out:
# (200, 71)

# %%
ds.head()
# Out:
#                                     Flow_ID           Src_IP  ...   Cat    Sub_Cat
# 0  192.168.100.147-192.168.100.3-62006-80-6  192.168.100.147  ...  DDoS   DDoS_TCP
# 1  192.168.100.148-192.168.100.7-38320-80-6  192.168.100.148  ...   DoS    DoS_TCP
# 2  192.168.100.148-192.168.100.7-40565-80-6  192.168.100.148  ...   DoS    DoS_TCP
# 3  192.168.100.148-192.168.100.3-39904-80-6  192.168.100.148  ...  DDoS  DDoS_HTTP
# 4  192.168.100.148-192.168.100.7-62340-80-6  192.168.100.148  ...   DoS    DoS_TCP
#
# [5 rows x 71 columns]

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = ds.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(25,20))
#plot heat map
g=sns.heatmap(corrmat, cmap ="YlGnBu", vmax=1.0, center=0, vmin= -1.0,
            square=True, linewidths = 0.0) 
# g=sns.heatmap(df[top_corr_features].corr(),cmap="RdYlGn")
plt.savefig('CM_IoT_Botnet.pdf')
plt.savefig("CM_IoT_Botnet.svg")
plt.savefig("CM_IoT_Botnet.png")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
