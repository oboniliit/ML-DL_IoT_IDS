# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd 
from scipy.io import arff

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nRowsRead = 'None' # specify 'None' if want to read whole file
# Preprossed_data.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
dfTrain= arff.loadarff('/content/drive/MyDrive/KDDTrain20MultiClass.arff')
df= pd.DataFrame(dfTrain[0])
nRow, nCol = df.shape
print(f'There are {nRow} rows and {nCol} columns')
df = df.drop('num_outbound_cmds',axis=1)
# Out:
# There are 25192 rows and 42 columns

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(15,10))
#plot heat map
g=sns.heatmap(corrmat, cmap ="YlGnBu", vmax=1.0, center=0, vmin= -1.0,
            square=True, linewidths = 0.0) 
# g=sns.heatmap(df[top_corr_features].corr(),cmap="RdYlGn")
plt.savefig('CM_NSL.pdf')
plt.savefig("CM_NSL_KDDTrain20")

# %%
dfTrain.head()
# Out:
#    duration  src_bytes  dst_bytes  land  ...  protocol_type  service  flag  xAttack
# 0       0.0      491.0        0.0  b'0'  ...           b'1'    b'20'  b'2'     b'5'
# 1       0.0      146.0        0.0  b'0'  ...           b'3'    b'45'  b'2'     b'5'
# 2       0.0        0.0        0.0  b'0'  ...           b'1'    b'50'  b'4'     b'1'
# 3       0.0      232.0     8153.0  b'0'  ...           b'1'    b'25'  b'2'     b'5'
# 4       0.0      199.0      420.0  b'0'  ...           b'1'    b'25'  b'2'     b'5'
#
# [5 rows x 42 columns]

# %%
nRowsRead = 'None' # specify 'None' if want to read whole file
# Preprossed_data.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
dfTest= arff.loadarff('/content/drive/MyDrive/KDDTest21MultiClass.arff')
ds = pd.DataFrame(dfTest[0])
nRow, nCol = ds.shape
print(f'There are {nRow} rows and {nCol} columns')
ds.head()
ds = ds.drop('num_outbound_cmds',axis=1)
# Out:
# There are 11850 rows and 42 columns

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = ds.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(15,8))
#plot heat map
g=sns.heatmap(ds[top_corr_features].corr(),annot=True,cmap="RdYlGn")
plt.savefig("CM_NSL_KDDTest21")
